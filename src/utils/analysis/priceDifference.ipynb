# %%
import psycopg2
from psycopg2 import sql
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from dotenv import load_dotenv
import os

# %%
# load environment variables
load_dotenv("../../../.env")

dbParams = {
    "host": os.getenv("db_host"),
    "port": os.getenv("db_port"),
    "user": os.getenv("db_username"),
    "password": os.getenv("db_password"),
    "database": os.getenv("db_name")
}

try:
    # Establish the connection
    conn = psycopg2.connect(**dbParams)
except Exception as e:
    print(f"Exception occurred: {e}")

# %%
# Set the cursor
cursor = conn.cursor()

# The query
query = "SELECT * from prices WHERE"
cursor.execute(query)
results = cursor.fetchall()

# %%
results
# Out:
# [('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 56, 747000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1813.9238359675999')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 56, 970000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 115000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1817.3259893248548')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 166000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 323000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 345000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1816.4909299946744')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 492000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 514000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 660000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 57, 838000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1816.4274228399127')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 58, 24000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1817.8758477694232')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 58, 46000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.791195973957')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 58, 211000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 58, 416000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 58, 636000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 58, 819000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1816.740324981306')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 59, 21000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 59, 199000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 59, 388000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.4841023524525')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 59, 564000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 59, 745000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 46, 59, 910000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 0, 96000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.9397319868667')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 0, 287000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 0, 455000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 0, 748000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1816.402990228167')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 0, 916000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1817.135214384804')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 6, 625000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1817.3259893248548')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 6, 691000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1813.9238359675999')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 6, 810000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 6, 902000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 6, 984000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 77000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 156000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 310000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1816.4274228399127')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 364000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1816.4909299946744')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 501000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1817.963048108226')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 534000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 679000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 7, 833000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 8, 1000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 8, 31000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.791195973957')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 8, 173000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1816.7408253478975')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 8, 352000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 8, 529000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 9, 68000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.4841023524525')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 9, 250000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 9, 811000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 10, 42000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 10, 224000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.9397319868667')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 10, 485000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 10, 705000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 16, 554000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1813.9238359675999')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 16, 727000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 16, 906000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 17, 105000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1816.4909299946744')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 17, 285000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 17, 480000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1816.402990228167')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 17, 652000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1817.135214384804')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 17, 821000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1817.3259893248548')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 13000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 204000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 380000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 556000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1816.4274228399127')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 646000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.791195973957')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 716000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1817.963048108226')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 18, 884000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 19, 49000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 19, 244000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 19, 429000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1816.7408253478975')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 19, 592000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 19, 770000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 19, 942000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.4841023524525')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 20, 93000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 20, 263000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 20, 433000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 20, 606000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.9397319868667')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 20, 932000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 21, 148000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 26, 260000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1817.3259893248548')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 26, 436000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 26, 581000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1813.9238359675999')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 26, 593000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 26, 781000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 26, 972000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1816.4274228399127')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 65000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 139000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1817.963048108226')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 258000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 311000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 473000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1816.4909299946744')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 495000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 644000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 666000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 27, 844000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1816.7408253478975')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 32000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 191000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.791195973957')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 205000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 389000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.4841023524525')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 577000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 761000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 28, 946000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 29, 106000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.9397319868667')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 29, 271000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 29, 442000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 29, 605000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1816.402990228167')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 29, 779000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1817.135214384804')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 36, 523000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1817.3259893248548')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 36, 545000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1813.9238359675999')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 36, 694000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 36, 715000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 36, 863000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 36, 890000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 42000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 48000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 200000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1816.4274228399127')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 211000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1816.4909299946744')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 364000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1817.963048108226')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 541000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 697000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.791195973957')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 725000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 37, 913000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 38, 100000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1815.9404148599124')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 38, 287000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 38, 467000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 38, 660000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.4841023524525')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 38, 862000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 39, 49000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 39, 238000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 39, 423000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.9397319868667')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 39, 616000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 39, 796000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 39, 983000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1815.4032532266804')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 40, 187000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1815.9083150351687')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 46, 526000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1817.3259893248548')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 46, 877000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 47, 959000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 48, 162000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1815.9404148599124')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 48, 347000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 48, 555000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 48, 743000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.4841023524525')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 48, 941000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 49, 97000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 49, 480000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 49, 660000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.9397319868667')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 49, 840000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 50, 22000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 50, 204000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1815.346195176786')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 50, 394000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1815.9083150351687')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 41, 802000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.580352329589')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 41, 976000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.63938805428')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 42, 148000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 42, 347000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 46, 652000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1816.9518639688838')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 46, 837000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 46, 924000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1818.2814870923642')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 42000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 147000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 258000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 345000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 509000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1814.8887113439894')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 525000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1814.497070724057')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 55, 47, 707000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 42, 805000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1818.629076987471')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 50, 568000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1814.895180154117')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 51, 878000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.881242248954')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 51, 933000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1818.1249817533485')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 52, 365000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 52, 772000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 52, 941000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1819.565648696019')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 53, 129000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 53, 299000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 53, 496000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.580352329589')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 53, 672000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6371553572508')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 53, 869000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 54, 59000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 54, 240000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1816.9518639688838')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 54, 426000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 54, 600000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1817.6518255749572')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 54, 787000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 54, 990000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 55, 181000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1819.3559459931785')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 55, 369000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1819.000134756805')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 57, 270000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 57, 617000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 57, 57, 774000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 7, 326000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 7, 530000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 7, 687000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 7, 694000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 7, 846000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.881242248954')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 17, 417000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 17, 846000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 58, 18, 195000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1818.1249817533485')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 46, 550000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1813.9238359675999')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 46, 698000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 46, 723000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 47, 46, 905000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
# ...
#   'curveProtocol',
#   'unknown',
#   Decimal('1814.497070724057')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 7, 784000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 7, 784000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 7, 974000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1814.7894303131138')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 8, 138000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1818.1249817533485')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 8, 288000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.6287170558141')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 8, 323000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 8, 508000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 8, 697000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 8, 884000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1815.1990139508332')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 9, 77000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 9, 263000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 9, 432000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.580352329589')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 9, 631000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 9, 849000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 10, 134000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 10, 654000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.3235991394981')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 11, 163000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x8ad599c3A0ff1De082011EFDDc58f1908eb6e6D8',
#   'uniswap',
#   'V3',
#   Decimal('1817.1118243377723')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 11, 343000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xA478c2975Ab1Ea89e8196811F51A7B7Ade33eB11',
#   'uniswap',
#   'V2',
#   Decimal('1817.3210477055388')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 11, 537000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x11b815efB8f581194ae79006d24E0d814B7697F6',
#   'uniswap',
#   'V3',
#   Decimal('1814.569619114657')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 11, 743000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x60594a405d53811d3BC4766596EFD80fd545A270',
#   'uniswap',
#   'V3',
#   Decimal('1814.7896052582223')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 16, 490000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1816.9518639688838')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 16, 716000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 16, 784000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1815.0679872675519')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 16, 943000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 16000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 219000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 228000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 425000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1814.7894303131138')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 431000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1814.497070724057')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 626000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 17, 850000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x72c2178E082feDB13246877B5aA42ebcE1b72218',
#   'sushiswap',
#   'V3',
#   Decimal('1837.0505360363454')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 18, 106000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x35644Fb61aFBc458bf92B15AdD6ABc1996Be5014',
#   'sushiswap',
#   'V3',
#   Decimal('1829.1099149739152')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 18, 319000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.6287170558141')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 18, 330000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC3D03e4F041Fd4cD388c549Ee2A29a9E5075882f',
#   'sushiswap',
#   'V2',
#   Decimal('1817.3829457679556')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 18, 528000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x88e6A0c2dDD26FEEb64F039a2c41296FcB3f5640',
#   'uniswap',
#   'V3',
#   Decimal('1815.1982383359687')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 18, 734000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xa80964C5bBd1A0E95777094420555fead1A26c1e',
#   'uniswap',
#   'V3',
#   Decimal('1829.7200272107195')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 18, 931000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x763d3b7296e7C9718AD5B058aC2692A19E5b3638',
#   'sushiswap',
#   'V3',
#   Decimal('1821.9991978985024')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 19, 148000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x06da0fd433C1A5d7a4faa01111c044910A184553',
#   'sushiswap',
#   'V2',
#   Decimal('1816.580352329589')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 19, 353000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x4e68Ccd3E89f51C3074ca5072bbAC773960dFa36',
#   'uniswap',
#   'V3',
#   Decimal('1816.6393537890585')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 19, 538000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 19, 727000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 26, 795000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1815.0679872675519')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 26, 979000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 27, 164000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 27, 331000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1814.497070724057')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 27, 533000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 28, 106000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7F86Bf177Dd4F3494b841a37e810A34dD56c829B',
#   'curveProtocol',
#   'unknown',
#   Decimal('1817.6287170558141')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 36, 765000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1815.0679872675519')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 36, 944000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 37, 154000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 37, 363000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xf5f5B97624542D72A9E06f04804Bf81baA15e2B4',
#   'curveProtocol',
#   'unknown',
#   Decimal('1814.497070724057')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 37, 572000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 52, 38, 47000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc',
#   'uniswap',
#   'V2',
#   Decimal('1818.2308705226787')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 42, 465000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x7BeA39867e4169DBe237d55C8242a8f2fcDcc387',
#   'uniswap',
#   'V3',
#   Decimal('1830.451038436239')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 42, 647000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x6a11ED98B1a3ac36A768ebbbbA36DED101Da5a3f',
#   'sushiswap',
#   'V3',
#   Decimal('2695.679006685105')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 46, 698000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x1D437AC0a77d9d0Ab6A512A6b054930Aa582A5B7',
#   'sushiswap',
#   'V3',
#   Decimal('1832.906439497389')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 46, 882000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC2e9F25Be6257c210d7Adf0D4Cd6E3E881ba25f8',
#   'uniswap',
#   'V3',
#   Decimal('1816.9518639688838')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 46, 976000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xD51a44d3FaE010294C616388b506AcdA1bfAAE46',
#   'curveProtocol',
#   'tricrypto2',
#   Decimal('1818.2814870923642')),
#  ('weth/dai',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 44000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x769DB46F39C42ee7AD5f71F4167c47EdD281E767',
#   'sushiswap',
#   'V3',
#   Decimal('1833.0433824076456')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 171000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80441ed630A10f2A36955c993c2D45bd9F848AF5',
#   'curveProtocol',
#   'unknown',
#   Decimal('3791.666836734694')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 232000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0xC5aF84701f98Fa483eCe78aF83F11b6C38ACA71D',
#   'uniswap',
#   'V3',
#   Decimal('1829.976487904359')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 330000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x5426178799ee0a0181A89b4f57eFddfAb49941Ec',
#   'curveProtocol',
#   'unknown',
#   Decimal('1813.7647686728442')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 411000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x0d4a11d5EEaaC28EC3F61d100daF4d40471f1852',
#   'uniswap',
#   'V2',
#   Decimal('1814.895180154117')),
#  ('weth/usdt',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 516000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x80466c64868E1ab14a1Ddf27A676C3fcBE638Fe5',
#   'curveProtocol',
#   'tricrypto',
#   Decimal('1819.8735577751947')),
#  ('weth/usdc',
#   'eth',
#   datetime.datetime(2025, 5, 3, 20, 56, 47, 580000, tzinfo=datetime.timezone(datetime.timedelta(seconds=12600))),
#   '0x397FF1542f962076d0BFE58eA045FfA2d347ACa0',
#   'sushiswap',
#   'V2',
#   Decimal('1818.1249817533485')),
#  ...]
